# %% [markdown]
# # **Text preprocessing**
# Merupakan salah satu implementasi dari text mining. Text mining sendiri adalah suatu kegiatan menambang data, dimana data yang biasanya diambil berupa text.
#
# Text preprocessing adalah suatu proses untuk menyeleksi data text agar menjadi lebih terstruktur lagi dengan melalui serangkaian tahapan yang meliputi tahapan case folding, tokenizing, filtering dan stemming

# %% [markdown]
# # **CaseFolding**
# Proses case folding adalah proses mengubah seluruh huruf menjadi huruf kecil. Pada proses ini karakter-karakter 'A'-'Z' yang terdapat pada data diubah kedalam karakter 'a'-'z'.

# %%
kalimat = '''Indonesia itu indah, terdapat pulau besar seperti Jawa, 
Kalimantan, Sumatera, Sulawesi, Bali, Papua'''
lower_case = kalimat.lower()
print(lower_case)
# output
# berikut ini adalah 5 negara dengan pendidikan terbaik di dunia adalah korea selatan, jepang, singapura, hong kong, dan finlandia.
# Out:
# indonesia itu indah, terdapat pulau besar seperti jawa, kalimantan, sumatera, sulawesi, bali, papua

# %% [markdown]
# # **Data Cleaning**

# %%
# cleaning non alpha-numeric
import re # impor modul regular expression
txt = 'Hi! @Mukidi, apa kabar? #sapa_Pagi.'
print(re.sub(r'[^\w]',' ',txt))
# atau jika ingin exclude titik dan koma 
# re.sub(r'[^.,a-zA-Z0-9 \n\.]','',txt)
# Out:
# Hi   Mukidi  apa kabar   sapa_Pagi

# %%
# Cleaning hashTags dalam posting media sosial
tweet = '#AndaiSajaIaTahu #ApaYangAkuRasah... #AlayersTweet #d2d'

getHashtags = re.compile(r"#(\w+)")
print("Tags = {0}".format(re.findall(getHashtags, tweet)))
# Out:
# Tags = ['AndaiSajaIaTahu', 'ApaYangAkuRasah', 'AlayersTweet', 'd2d']

# %%
# Extracting atau replacing eMail.
emailPattern = re.compile(r'[\w._%+-]+@[\w\.-]+\.[a-zA-Z]{2,4}')

txt = '''Contact kami di admin@nlpindonesia.org, nlp.indonesia@sci.yahoo.co.id, 
atau nlp_nusantara@internet.net'''

print( re.sub(emailPattern, ' ', txt) )# clean email
eMailS = re.findall( emailPattern, txt )
print( 'email yang ditemukan: ', str(eMailS) )
# Out:
# Contact kami di  ,  , atau
# email yang ditemukan:  ['admin@nlpindonesia.org', 'nlp.indonesia@sci.yahoo.co.id', 'nlp_nusantara@internet.net']

# %%
kalimat = "Terdapat 5 jenis ikan dikolam itu, lele, gurami, nila, patin, mas"
hasil = re.sub(r"\d+", "", kalimat)
print(hasil)
# Out:
# Terdapat  jenis ikan dikolam itu, lele, gurami, nila, patin, mas

# %%
kalimat="Terdapat 5 jenis ikan di kolam itu lele, gurami, nila, patin, mas 3"
hasil=re.compile(r"\d+")
# print(hasil)
angka = re.findall(hasil,kalimat)
print('Angka yang ditemukan: ', str(angka))
# Out:
# Angka yang ditemukan:  ['5', '3']

# %%
kalimat="Terdapat 5 jenis ikan di kolam itu lele, gurami, nila, patin, mas 3"
hasil=re.sub(r'[^0-9 \n\.]', "", kalimat)
print(hasil)
# Out:
#  5           3

# %%
# Website URLS http(s) .... untuk ftp trivial
urlPattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')

txt = 'website reguler expression & my site : https://www.regular-expressions.info/ & https://tau-data.id'
print(re.sub(urlPattern,' ',txt))# clean urls

URLs = re.findall(urlPattern,txt)# get URLs
print('URL yang ditemukan: ',str(URLs))
# Out:
# website reguler expression & my site :   &
# URL yang ditemukan:  ['https://www.regular-expressions.info/', 'https://tau-data.id']

# %% [markdown]
# # **Tokenizing**
# Tokenizing adalah proses pemisahan teks menjadi potongan-potongan yang disebut sebagai token untuk kemudian di analisa. Kata, angka, simbol, tanda baca dan entitas penting lainnya dapat dianggap sebagai token. Didalam NLP, token diartikan sebagai “kata” meskipun tokenize juga dapat dilakukan pada paragraf maupun kalimat

# %% [markdown]
# ***Tokenizing kata***

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.1)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# impor word_tokenize dari modul nltk

from nltk.tokenize import word_tokenize 
 
kalimat = "Kita sedang belajar Data Mining, materi pre-processing."
 
tokens = nltk.tokenize.word_tokenize(kalimat)
print(tokens)
# ouput 
# ['Kita', 'sedang', 'belajar', 'Data', 'Mining', ',', 'materi', 'pre-processing', '.']
# Out:
# ['Kita', 'sedang', 'belajar', 'Data', 'Mining', ',', 'materi', 'pre-processing', '.']

# %%
#token kata bisa digunakan untuk menghitung kwmunculan kata
from nltk.probability import FreqDist
kalimat = '''Lala sering sekali berbelanja online terutama pada saat pandemi. 
Menurut lala belanja online lebih praktis daripada belanja di pasar.'''

tokens = nltk.tokenize.word_tokenize(kalimat)
kemunculan = nltk.FreqDist(tokens)
print(kemunculan.most_common())
# Out:
# [('online', 2), ('.', 2), ('belanja', 2), ('Lala', 1), ('sering', 1), ('sekali', 1), ('berbelanja', 1), ('terutama', 1), ('pada', 1), ('saat', 1), ('pandemi', 1), ('Menurut', 1), ('lala', 1), ('lebih', 1), ('praktis', 1), ('daripada', 1), ('di', 1), ('pasar', 1)]

# %%
from nltk.probability import FreqDist
kalimat="Lala sering sekali berbelanja online terutama pada saat pandemi . Menurut lala belanja online lebih praktis daripada belanja di pasar."

lower_case=kalimat.lower()
kal=re.sub(r'[^\w]',' ',lower_case)

tokens=nltk.tokenize.word_tokenize(kal)
kemunculan=nltk.FreqDist(tokens)
print(kemunculan.most_common())
# Out:
# [('lala', 2), ('online', 2), ('belanja', 2), ('sering', 1), ('sekali', 1), ('berbelanja', 1), ('terutama', 1), ('pada', 1), ('saat', 1), ('pandemi', 1), ('menurut', 1), ('lebih', 1), ('praktis', 1), ('daripada', 1), ('di', 1), ('pasar', 1)]

# %% [markdown]
# **Tokenizing Kalimat**

# %%
# impor sent_tokenize dari modul nltk
from nltk.tokenize import sent_tokenize
kalimat = '''Kita sedang belajar Data Mining, materi pre-processing. 
sub materi tokenizing. menyenangkan bukaaaan'''
 
tokens = nltk.tokenize.sent_tokenize(kalimat)
print(tokens)
# ouput
# ['Kita sedang belajar Data Mining, materi pre-processing.', 'sub materi tokenizing.', 'menyenangkan bukaaaan']
# Out:
# ['Kita sedang belajar Data Mining, materi pre-processing.', 'sub materi tokenizing.', 'menyenangkan bukaaaan']

# %% [markdown]
# # **Filtering (Stopword Removal)**
# Stopword adalah kata umum yang biasanya muncul dalam jumlah besar dan dianggap tidak memiliki makna. Contoh stopword dalam bahasa Indonesia adalah “yang”, “dan”, “di”, “dari”, dll. Makna di balik penggunaan stopword yaitu dengan menghapus kata-kata yang memiliki informasi rendah dari sebuah teks, kita dapat fokus pada kata-kata penting sebagai gantinya.

# %%
from nltk.corpus import stopwords
 
kalimat = '''Lala sering sekali berbelanja online terutama pada saat pandemi. 
Menurut lala belanja online dan lebih praktis daripada belanja di pasar.'''

tokens = word_tokenize(kalimat)
listStopword =  set(stopwords.words('indonesian'))
 
removed = []
for t in tokens:
    if t not in listStopword:
        removed.append(t)
 
print(removed)
# Out:
# ['Lala', 'berbelanja', 'online', 'pandemi', '.', 'Menurut', 'lala', 'belanja', 'online', 'praktis', 'belanja', 'pasar', '.']

# %% [markdown]
# # **Stemming**
# Stemming adalah proses pemetaan dan penguraian bentuk dari suatu kata menjadi bentuk kata dasarnya.
# Untuk melakukan stemming bahasa Indonesia kita dapat menggunakan library Python Sastrawi yang sudah kita siapkan di awal. Library Sastrawi menerapkan Algoritma Nazief dan Adriani dalam melakukan stemming bahasa Indonesia.

# %%
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.7/dist-packages (1.0.1)

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()
 
kalimat = "Lala sering sekali berbelanja online terutama pada saat pandemi. Menurut lala belanja online dan lebih praktis daripada belanja di pasar."
hasil = stemmer.stem(kalimat)
print(hasil)
# Out:
# lala sering sekali belanja online utama pada saat pandemi turut lala belanja online dan lebih praktis daripada belanja di pasar

# %% [markdown]
# # **Contoh Text Pre-Processing pada dataset**

# %%
import pandas as pd
df = pd.read_csv('ReviewHotel50.csv')
df.head()
# Out:
#                                               review  service
# 0  Saya kehilangan barang saya yang kelupaan di k...        0
# 1  Hotel ini terletak di daerah terpencil di jala...        0
# 2  Check innya lama banget kamar belum siap katan...        0
# 3  Ini kedua kalinya keluarga saya menginap di vi...        1
# 4  Saya pilih kamar yang ternyata kamar mandinya ...        1

# %%
import re
def  clean_text(df, text_field, new_text_field_name):
    df[new_text_field_name] = df[text_field].str.lower()
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))  
    # remove numbers
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"\d+", "", elem)) 
    return df

# %%
df['text_clean'] = df['review'].str.lower()
df['text_clean']
data_clean = clean_text(df, 'review', 'text_clean')
data_clean.head(10)
# Out:
#                                               review  service  \
# 0  Saya kehilangan barang saya yang kelupaan di k...        0
# 1  Hotel ini terletak di daerah terpencil di jala...        0
# 2  Check innya lama banget kamar belum siap katan...        0
# 3  Ini kedua kalinya keluarga saya menginap di vi...        1
# 4  Saya pilih kamar yang ternyata kamar mandinya ...        1
# 5  Kamar tidak kedap suarasuara dari luar sangar ...        1
# 6  Sarapannya dimulai jam 17.11 terlalu siang unt...        1
# 7  Oke tapi untuk housekeepingnya tolong lebih ba...        0
# 8  Makanan oke banget lengkap menunya. Hanya saja...        0
# 9  Jalur masuk menuju kamar mirip labirin panjang...        1
#
#                                           text_clean
# 0  saya kehilangan barang saya yang kelupaan di k...
# 1  hotel ini terletak di daerah terpencil di jala...
# 2  check innya lama banget kamar belum siap katan...
# 3  ini kedua kalinya keluarga saya menginap di vi...
# 4  saya pilih kamar yang ternyata kamar mandinya ...
# 5  kamar tidak kedap suarasuara dari luar sangar ...
# 6  sarapannya dimulai jam  terlalu siang untuk wi...
# 7  oke tapi untuk housekeepingnya tolong lebih ba...
# 8  makanan oke banget lengkap menunya hanya saja ...
# 9  jalur masuk menuju kamar mirip labirin panjang...

# %%
#------STOPWORDS--------------------
import nltk.corpus
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('indonesian')
data_clean['text_StopWord'] = data_clean['text_clean'].apply(lambda x:' '.join([word for word in x.split() if word not in (stop)]))
data_clean.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                               review  service  \
# 0  Saya kehilangan barang saya yang kelupaan di k...        0
# 1  Hotel ini terletak di daerah terpencil di jala...        0
# 2  Check innya lama banget kamar belum siap katan...        0
# 3  Ini kedua kalinya keluarga saya menginap di vi...        1
# 4  Saya pilih kamar yang ternyata kamar mandinya ...        1
#
#                                           text_clean  \
# 0  saya kehilangan barang saya yang kelupaan di k...
# 1  hotel ini terletak di daerah terpencil di jala...
# 2  check innya lama banget kamar belum siap katan...
# 3  ini kedua kalinya keluarga saya menginap di vi...
# 4  saya pilih kamar yang ternyata kamar mandinya ...
#
#                                        text_StopWord
# 0  kehilangan barang kelupaan kulkas menghubungi ...
# 1  hotel terletak daerah terpencil jalan sempit m...
# 2  check innya banget kamar book jauhjauh kamar s...
# 3  kalinya keluarga menginap viva hotel penginapa...
# 4  pilih kamar kamar mandinya lantai kamar mandin...

# %%
#--------#TOKONIZE----------------
import nltk 
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
data_clean['text_tokens'] = data_clean['text_StopWord'].apply(lambda x: word_tokenize(x))
data_clean.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                               review  service  \
# 0  Saya kehilangan barang saya yang kelupaan di k...        0
# 1  Hotel ini terletak di daerah terpencil di jala...        0
# 2  Check innya lama banget kamar belum siap katan...        0
# 3  Ini kedua kalinya keluarga saya menginap di vi...        1
# 4  Saya pilih kamar yang ternyata kamar mandinya ...        1
#
#                                           text_clean  \
# 0  saya kehilangan barang saya yang kelupaan di k...
# 1  hotel ini terletak di daerah terpencil di jala...
# 2  check innya lama banget kamar belum siap katan...
# 3  ini kedua kalinya keluarga saya menginap di vi...
# 4  saya pilih kamar yang ternyata kamar mandinya ...
#
#                                        text_StopWord  \
# 0  kehilangan barang kelupaan kulkas menghubungi ...
# 1  hotel terletak daerah terpencil jalan sempit m...
# 2  check innya banget kamar book jauhjauh kamar s...
# 3  kalinya keluarga menginap viva hotel penginapa...
# 4  pilih kamar kamar mandinya lantai kamar mandin...
#
#                                          text_tokens
# 0  [kehilangan, barang, kelupaan, kulkas, menghub...
# 1  [hotel, terletak, daerah, terpencil, jalan, se...
# 2  [check, innya, banget, kamar, book, jauhjauh, ...
# 3  [kalinya, keluarga, menginap, viva, hotel, pen...
# 4  [pilih, kamar, kamar, mandinya, lantai, kamar,...

# %%
#-----------------STEMMING -----------------
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
#import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}
hitung=0

for document in data_clean['text_tokens']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")
for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    hitung+=1
    print(hitung,":",term,":" ,term_dict[term])

print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]


#script ini bisa dipisah dari eksekusinya setelah pembacaaan term selesai
data_clean['text_steamindo'] = data_clean['text_tokens'].apply(lambda x:' '.join(get_stemmed_term(x)))
data_clean.head(20)
# Out:
# 420
# ------------------------
# 1 : kehilangan : hilang
# 2 : barang : barang
# 3 : kelupaan : lupa
# 4 : kulkas : kulkas
# 5 : menghubungi : hubung
# 6 : hotel : hotel
# 7 : respon : respon
# 8 : terletak : letak
# 9 : daerah : daerah
# 10 : terpencil : pencil
# 11 : jalan : jalan
# 12 : sempit : sempit
# 13 : membawa : bawa
# 14 : mobil : mobil
# 15 : menyewa : sewa
# 16 : sopir : sopir
# 17 : check : check
# 18 : innya : innya
# 19 : banget : banget
# 20 : kamar : kamar
# 21 : book : book
# 22 : jauhjauh : jauhjauh
# 23 : sarapan : sarap
# 24 : pagi : pagi
# 25 : jam : jam
# 26 : lauk : lauk
# 27 : tinggal : tinggal
# 28 : dikit : dikit
# 29 : kalinya : kali
# 30 : keluarga : keluarga
# 31 : menginap : inap
# 32 : viva : viva
# 33 : penginapan : inap
# 34 : kali : kali
# 35 : mengecewakan : kecewa
# 36 : ruang : ruang
# 37 : dbanding : dbanding
# 38 : pilih : pilih
# 39 : mandinya : mandi
# 40 : lantai : lantai
# 41 : gayung : gayung
# 42 : airnya : air
# 43 : sulit : sulit
# 44 : bab : bab
# 45 : buang : buang
# 46 : air : air
# 47 : menyiramnya : siram
# 48 : dikasih : kasih
# 49 : tau : tau
# 50 : petugas : tugas
# 51 : resepsionis : resepsionis
# 52 : kedap : kedap
# 53 : suarasuara : suarasuara
# 54 : sangar : sangar
# 55 : kedengaran : dengar
# 56 : berisikapalagi : berisikapalagi
# 57 : kemarin : kemarin
# 58 : ballroom : ballroom
# 59 : acaraberisik : acaraberisik
# 60 : terganggu : ganggu
# 61 : istirahat : istirahat
# 62 : sarapannya : sarap
# 63 : siang : siang
# 64 : wilayah : wilayah
# 65 : jakarta : jakarta
# 66 : aktivitas : aktivitas
# 67 : nasi : nasi
# 68 : orang : orang
# 69 : indonesia : indonesia
# 70 : oke : oke
# 71 : housekeepingnya : housekeepingnya
# 72 : tolong : tolong
# 73 : makeup : makeup
# 74 : room : room
# 75 : malam : malam
# 76 : bersihin : bersihin
# 77 : bilang : bilang
# 78 : prioritas : prioritas
# 79 : aneh : aneh
# 80 : makanan : makan
# 81 : lengkap : lengkap
# 82 : menunya : menu
# 83 : handuk : handuk
# 84 : keset : keset
# 85 : langsung : langsung
# 86 : tersedia : sedia
# 87 : pintu : pintu
# 88 : mandi : mandi
# 89 : seret : seret
# 90 : buka : buka
# 91 : tutupnya : tutup
# 92 : jalur : jalur
# 93 : masuk : masuk
# 94 : labirin : labirin
# 95 : makan : makan
# 96 : disukai : suka
# 97 : anakanak : anakanak
# 98 : parkiran : parkir
# 99 : kamarnya : kamar
# 100 : sayang : sayang
# 101 : pas : pas
# 102 : dateng : dateng
# 103 : alasan : alas
# 104 : blm : blm
# 105 : selesai : selesai
# 106 : bereskan : beres
# 107 : enak : enak
# 108 : pusat : pusat
# 109 : kota : kota
# 110 : bioskop : bioskop
# 111 : pokoknya : pokok
# 112 : sip : sip
# 113 : deh : deh
# 114 : tempatnya : tempat
# 115 : bagus : bagus
# 116 : bersih : bersih
# 117 : harga : harga
# 118 : murah : murah
# 119 : m : m
# 120 : masuknya : masuk
# 121 : in : in
# 122 : gelap : gelap
# 123 : strategis : strategis
# 124 : kemana : mana
# 125 : ac : ac
# 126 : dingin : dingin
# 127 : edisi : edisi
# 128 : suara : suara
# 129 : tenang : tenang
# 130 : acara : acara
# 131 : peduli : peduli
# 132 : bangun : bangun
# 133 : pergi : pergi
# 134 : skouw : skouw
# 135 : perbatasan : batas
# 136 : ripng : ripng
# 137 : mengambil : ambil
# 138 : layanannya : layan
# 139 : menyenangkankecuali : menyenangkankecuali
# 140 : diperhatikan : perhati
# 141 : tamu : tamu
# 142 : isengsoalnya : isengsoalnya
# 143 : bel : bel
# 144 : maininganggu : maininganggu
# 145 : org : org
# 146 : tidur : tidur
# 147 : aja : aja
# 148 : sudutsudut : sudutsudut
# 149 : kotor : kotor
# 150 : lembab : lembab
# 151 : panas : panas
# 152 : berfungsi : fungsi
# 153 : kirain : kirain
# 154 : rusak : rusak
# 155 : baca : baca
# 156 : review : review
# 157 : kebagian : bagi
# 158 : makanannya : makan
# 159 : sih : sih
# 160 : standar : standar
# 161 : compare : compare
# 162 : neo : neo
# 163 : enaklah : enak
# 164 : gelasnya : gelas
# 165 : bekas : bekas
# 166 : gitu : gitu
# 167 : tatakan : tata
# 168 : gelas : gelas
# 169 : ganti : ganti
# 170 : semoga : moga
# 171 : improve : improve
# 172 : menyesuaikan : sesuai
# 173 : mall : mall
# 174 : nyaman : nyaman
# 175 : berisik : berisik
# 176 : checkin : checkin
# 177 : menunggu : tunggu
# 178 : stengah : stengah
# 179 : prepare : prepare
# 180 : kamarsementara : kamarsementara
# 181 : checkout : checkout
# 182 : nya : nya
# 183 : on : on
# 184 : timeselebihnya : timeselebihnya
# 185 : ok : ok
# 186 : ketiga : tiga
# 187 : pesan : pesan
# 188 : wastafel : wastafel
# 189 : kloset : kloset
# 190 : berwarna : warna
# 191 : kuning : kuning
# 192 : shower : shower
# 193 : normal : normal
# 194 : menu : menu
# 195 : breakfast : breakfast
# 196 : koskosan : koskosan
# 197 : permukiman : mukim
# 198 : warga : warga
# 199 : kondisi : kondisi
# 200 : tinggali : tinggal
# 201 : tdnya : tdnya
# 202 : rencana : rencana
# 203 : area : area
# 204 : meeting : meeting
# 205 : urungkan : urung
# 206 : niat : niat
# 207 : situ : situ
# 208 : pelayanan : layan
# 209 : keamanan : aman
# 210 : parkir : parkir
# 211 : buruk : buruk
# 212 : helm : helm
# 213 : motor : motor
# 214 : hilang : hilang
# 215 : berbintang : bintang
# 216 : lampu : lampu
# 217 : redup : redup
# 218 : mati : mati
# 219 : semut : semut
# 220 : bau : bau
# 221 : apek : apek
# 222 : kran : kran
# 223 : pindah : pindah
# 224 : sebentar : sebentar
# 225 : hitam : hitam
# 226 : berbau : bau
# 227 : nyamuk : nyamuk
# 228 : recommended : recommended
# 229 : stay : stay
# 230 : disana : sana
# 231 : complain : complain
# 232 : teknisinya : teknisi
# 233 : disarankan : saran
# 234 : fasilitas : fasilitas
# 235 : okhanya : okhanya
# 236 : penanganan : tangan
# 237 : thd : thd
# 238 : piringgelas : piringgelas
# 239 : meja : meja
# 240 : lamban : lamban
# 241 : lokasi : lokasi
# 242 : tombol : tombol
# 243 : meletakkan : letak
# 244 : mohon : mohon
# 245 : diperbaiki : baik
# 246 : selimut : selimut
# 247 : bercak : bercak
# 248 : kotoran : kotor
# 249 : toilet : toilet
# 250 : susah : susah
# 251 : diatur : atur
# 252 : temperaturnya : temperatur
# 253 : suka : suka
# 254 : timernya : timernya
# 255 : reset : reset
# 256 : posisi : posisi
# 257 : nembak : nembak
# 258 : kasur : kasur
# 259 : roti : roti
# 260 : blok : blok
# 261 : ukuran : ukur
# 262 : bed : bed
# 263 : yg : yg
# 264 : queen : queen
# 265 : croissant : croissant
# 266 : kopi : kopi
# 267 : teh : teh
# 268 : sbux : sbux
# 269 : just : just
# 270 : it : it
# 271 : hotelnya : hotel
# 272 : cuman : cuman
# 273 : pilihan : pilih
# 274 : peralatan : alat
# 275 : berdebu : debu
# 276 : closetnya : closetnya
# 277 : binatang : binatang
# 278 : cacing : cacing
# 279 : channel : channel
# 280 : tv : tv
# 281 : wifi : wifi
# 282 : parah : parah
# 283 : mini : mini
# 284 : market : market
# 285 : coffe : coffe
# 286 : tea : tea
# 287 : dikamar : kamar
# 288 : rokok : rokok
# 289 : sprei : sprei
# 290 : pusing : pusing
# 291 : tidurnya : tidur
# 292 : kerja : kerja
# 293 : terdengar : dengar
# 294 : jendela : jendela
# 295 : view : view
# 296 : gudang : gudang
# 297 : keliatan : liat
# 298 : tumpukan : tumpu
# 299 : karpetkarpet : karpetkarpet
# 300 : plaffon : plaffon
# 301 : bolong : bolong
# 302 : spertinya : spertinya
# 303 : mengintip : intip
# 304 : stasiun : stasiun
# 305 : bandung : bandung
# 306 : malammalam : malammalam
# 307 : kelaparan : lapar
# 308 : warung : warung
# 309 : minimarket : minimarket
# 310 : ruanganan : ruanganan
# 311 : lorong : lorong
# 312 : menyeramkan : seram
# 313 : lift : lift
# 314 : desain : desain
# 315 : oketapi : oketapi
# 316 : ngeselin : ngeselin
# 317 : putus : putus
# 318 : breakfastnya : breakfastnya
# 319 : no : no
# 320 : comment : comment
# 321 : biarkan : biar
# 322 : bintang : bintang
# 323 : mengartikan : arti
# 324 : kritik : kritik
# 325 : saran : saran
# 326 : security : security
# 327 : sigap : sigap
# 328 : keruh : keruh
# 329 : warna : warna
# 330 : tunggu : tunggu
# 331 : jaganya : jaga
# 332 : ramah : ramah
# 333 : senyum : senyum
# 334 : terkecuali : kecuali
# 335 : staff : staff
# 336 : restaurant : restaurant
# 337 : cashier : cashier
# 338 : pd : pd
# 339 : bill : bill
# 340 : membutuhkan : butuh
# 341 : menit : menit
# 342 : bayar : bayar
# 343 : nunggu : nunggu
# 344 : kembalian : kembali
# 345 : butuh : butuh
# 346 : strategi : strategi
# 347 : memilih : pilih
# 348 : ex : ex
# 349 : mal : mal
# 350 : dipaksa : paksa
# 351 : hoteljadi : hoteljadi
# 352 : layoutnya : layoutnya
# 353 : interior : interior
# 354 : pelan : pelan
# 355 : disewa : sewa
# 356 : reuni : reuni
# 357 : sd : sd
# 358 : musik : musik
# 359 : lalang : lalang
# 360 : keras : keras
# 361 : koridor : koridor
# 362 : aliran : alir
# 363 : lancar : lancar
# 364 : wc : wc
# 365 : licin : licin
# 366 : bocor : bocor
# 367 : dinginnya : dingin
# 368 : listrik : listrik
# 369 : tibatiba : tibatiba
# 370 : cabut : cabut
# 371 : kartu : kartu
# 372 : nyala : nyala
# 373 : pinggir : pinggir
# 374 : houskeepingnya : houskeepingnya
# 375 : payahhanduk : payahhanduk
# 376 : ambil : ambil
# 377 : tehkopi : tehkopi
# 378 : with : with
# 379 : compliment : compliment
# 380 : lengkapi : lengkap
# 381 : chef : chef
# 382 : omlet : omlet
# 383 : jutek : jutek
# 384 : mencoba : coba
# 385 : raja : raja
# 386 : penuh : penuh
# 387 : arried : arried
# 388 : menutup : tutup
# 389 : tua : tua
# 390 : berencana : rencana
# 391 : menakutkan : takut
# 392 : dianjurkan : anjur
# 393 : bepergian : pergi
# 394 : mengangkat : angkat
# 395 : koper : koper
# 396 : tangga : tangga
# 397 : lumayan : lumayan
# 398 : blowernya : blower
# 399 : mendengar : dengar
# 400 : tikus : tikus
# 401 : plafon : plafon
# 402 : shock : shock
# 403 : memiliki : milik
# 404 : pengalaman : alam
# 405 : sekelas : kelas
# 406 : tsb : tsb
# 407 : serasa : serasa
# 408 : terkunci : kunci
# 409 : pelayanannya : layan
# 410 : memuaskan : muas
# 411 : remote : remote
# 412 : diganti : ganti
# 413 : sower : sower
# 414 : westafel : westafel
# 415 : ramai : ramai
# 416 : selera : selera
# 417 : habis : habis
# 418 : kamarbijaksana : kamarbijaksana
# 419 : apaapa : apaapa
# 420 : diharapkan : harap
# {'kehilangan': 'hilang', 'barang': 'barang', 'kelupaan': 'lupa', 'kulkas': 'kulkas', 'menghubungi': 'hubung', 'hotel': 'hotel', 'respon': 'respon', 'terletak': 'letak', 'daerah': 'daerah', 'terpencil': 'pencil', 'jalan': 'jalan', 'sempit': 'sempit', 'membawa': 'bawa', 'mobil': 'mobil', 'menyewa': 'sewa', 'sopir': 'sopir', 'check': 'check', 'innya': 'innya', 'banget': 'banget', 'kamar': 'kamar', 'book': 'book', 'jauhjauh': 'jauhjauh', 'sarapan': 'sarap', 'pagi': 'pagi', 'jam': 'jam', 'lauk': 'lauk', 'tinggal': 'tinggal', 'dikit': 'dikit', 'kalinya': 'kali', 'keluarga': 'keluarga', 'menginap': 'inap', 'viva': 'viva', 'penginapan': 'inap', 'kali': 'kali', 'mengecewakan': 'kecewa', 'ruang': 'ruang', 'dbanding': 'dbanding', 'pilih': 'pilih', 'mandinya': 'mandi', 'lantai': 'lantai', 'gayung': 'gayung', 'airnya': 'air', 'sulit': 'sulit', 'bab': 'bab', 'buang': 'buang', 'air': 'air', 'menyiramnya': 'siram', 'dikasih': 'kasih', 'tau': 'tau', 'petugas': 'tugas', 'resepsionis': 'resepsionis', 'kedap': 'kedap', 'suarasuara': 'suarasuara', 'sangar': 'sangar', 'kedengaran': 'dengar', 'berisikapalagi': 'berisikapalagi', 'kemarin': 'kemarin', 'ballroom': 'ballroom', 'acaraberisik': 'acaraberisik', 'terganggu': 'ganggu', 'istirahat': 'istirahat', 'sarapannya': 'sarap', 'siang': 'siang', 'wilayah': 'wilayah', 'jakarta': 'jakarta', 'aktivitas': 'aktivitas', 'nasi': 'nasi', 'orang': 'orang', 'indonesia': 'indonesia', 'oke': 'oke', 'housekeepingnya': 'housekeepingnya', 'tolong': 'tolong', 'makeup': 'makeup', 'room': 'room', 'malam': 'malam', 'bersihin': 'bersihin', 'bilang': 'bilang', 'prioritas': 'prioritas', 'aneh': 'aneh', 'makanan': 'makan', 'lengkap': 'lengkap', 'menunya': 'menu', 'handuk': 'handuk', 'keset': 'keset', 'langsung': 'langsung', 'tersedia': 'sedia', 'pintu': 'pintu', 'mandi': 'mandi', 'seret': 'seret', 'buka': 'buka', 'tutupnya': 'tutup', 'jalur': 'jalur', 'masuk': 'masuk', 'labirin': 'labirin', 'makan': 'makan', 'disukai': 'suka', 'anakanak': 'anakanak', 'parkiran': 'parkir', 'kamarnya': 'kamar', 'sayang': 'sayang', 'pas': 'pas', 'dateng': 'dateng', 'alasan': 'alas', 'blm': 'blm', 'selesai': 'selesai', 'bereskan': 'beres', 'enak': 'enak', 'pusat': 'pusat', 'kota': 'kota', 'bioskop': 'bioskop', 'pokoknya': 'pokok', 'sip': 'sip', 'deh': 'deh', 'tempatnya': 'tempat', 'bagus': 'bagus', 'bersih': 'bersih', 'harga': 'harga', 'murah': 'murah', 'm': 'm', 'masuknya': 'masuk', 'in': 'in', 'gelap': 'gelap', 'strategis': 'strategis', 'kemana': 'mana', 'ac': 'ac', 'dingin': 'dingin', 'edisi': 'edisi', 'suara': 'suara', 'tenang': 'tenang', 'acara': 'acara', 'peduli': 'peduli', 'bangun': 'bangun', 'pergi': 'pergi', 'skouw': 'skouw', 'perbatasan': 'batas', 'ripng': 'ripng', 'mengambil': 'ambil', 'layanannya': 'layan', 'menyenangkankecuali': 'menyenangkankecuali', 'diperhatikan': 'perhati', 'tamu': 'tamu', 'isengsoalnya': 'isengsoalnya', 'bel': 'bel', 'maininganggu': 'maininganggu', 'org': 'org', 'tidur': 'tidur', 'aja': 'aja', 'sudutsudut': 'sudutsudut', 'kotor': 'kotor', 'lembab': 'lembab', 'panas': 'panas', 'berfungsi': 'fungsi', 'kirain': 'kirain', 'rusak': 'rusak', 'baca': 'baca', 'review': 'review', 'kebagian': 'bagi', 'makanannya': 'makan', 'sih': 'sih', 'standar': 'standar', 'compare': 'compare', 'neo': 'neo', 'enaklah': 'enak', 'gelasnya': 'gelas', 'bekas': 'bekas', 'gitu': 'gitu', 'tatakan': 'tata', 'gelas': 'gelas', 'ganti': 'ganti', 'semoga': 'moga', 'improve': 'improve', 'menyesuaikan': 'sesuai', 'mall': 'mall', 'nyaman': 'nyaman', 'berisik': 'berisik', 'checkin': 'checkin', 'menunggu': 'tunggu', 'stengah': 'stengah', 'prepare': 'prepare', 'kamarsementara': 'kamarsementara', 'checkout': 'checkout', 'nya': 'nya', 'on': 'on', 'timeselebihnya': 'timeselebihnya', 'ok': 'ok', 'ketiga': 'tiga', 'pesan': 'pesan', 'wastafel': 'wastafel', 'kloset': 'kloset', 'berwarna': 'warna', 'kuning': 'kuning', 'shower': 'shower', 'normal': 'normal', 'menu': 'menu', 'breakfast': 'breakfast', 'koskosan': 'koskosan', 'permukiman': 'mukim', 'warga': 'warga' ...
# ------------------------
#                                                review  service  \
# 0   Saya kehilangan barang saya yang kelupaan di k...        0
# 1   Hotel ini terletak di daerah terpencil di jala...        0
# 2   Check innya lama banget kamar belum siap katan...        0
# 3   Ini kedua kalinya keluarga saya menginap di vi...        1
# 4   Saya pilih kamar yang ternyata kamar mandinya ...        1
# 5   Kamar tidak kedap suarasuara dari luar sangar ...        1
# 6   Sarapannya dimulai jam 17.11 terlalu siang unt...        1
# 7   Oke tapi untuk housekeepingnya tolong lebih ba...        0
# 8   Makanan oke banget lengkap menunya. Hanya saja...        0
# 9   Jalur masuk menuju kamar mirip labirin panjang...        1
# 10  Kamarnya oke sayang pas dateng belum bisa lang...        0
# 11  Enak banget. Hotel terletak di pusat kota. Mau...        1
# 12  Tempatnya bagus dan Bersih untuk harga yang cu...        1
# 13  Edisi menginap kali ini karena kamar tidak ked...        1
# 14  Resepsionis itu peduli pada saya ketika saya p...        1
# 15  Sangat menyenangkan..kecuali mungkin harus leb...        1
# 16  Sudut-sudut kamar kotor kamar lembab air panas...        1
# 17  Saat check-in harus menunggu 1 stengah jam bua...        0
# 18  Dari ketiga kamar yang saya pesan dalam kamar ...        1
# 19  Tidak banget tempat sempit tidak cuma bisa mas...        1
#
#                                            text_clean  \
# 0   saya kehilangan barang saya yang kelupaan di k...
# 1   hotel ini terletak di daerah terpencil di jala...
# 2   check innya lama banget kamar belum siap katan...
# 3   ini kedua kalinya keluarga saya menginap di vi...
# 4   saya pilih kamar yang ternyata kamar mandinya ...
# 5   kamar tidak kedap suarasuara dari luar sangar ...
# 6   sarapannya dimulai jam  terlalu siang untuk wi...
# 7   oke tapi untuk housekeepingnya tolong lebih ba...
# 8   makanan oke banget lengkap menunya hanya saja ...
# 9   jalur masuk menuju kamar mirip labirin panjang...
# 10  kamarnya oke sayang pas dateng belum bisa lang...
# 11  enak banget hotel terletak di pusat kota mau k...
# 12  tempatnya bagus dan bersih untuk harga yang cu...
# 13  edisi menginap kali ini karena kamar tidak ked...
# 14  resepsionis itu peduli pada saya ketika saya p...
# 15  sangat menyenangkankecuali mungkin harus lebih...
# 16  sudutsudut kamar kotor kamar lembab air panas ...
# 17  saat checkin harus menunggu  stengah jam buat ...
# 18  dari ketiga kamar yang saya pesan dalam kamar ...
# 19  tidak banget tempat sempit tidak cuma bisa mas...
#
#                                         text_StopWord  \
# 0   kehilangan barang kelupaan kulkas menghubungi ...
# 1   hotel terletak daerah terpencil jalan sempit m...
# 2   check innya banget kamar book jauhjauh kamar s...
# 3   kalinya keluarga menginap viva hotel penginapa...
# 4   pilih kamar kamar mandinya lantai kamar mandin...
# 5   kamar kedap suarasuara sangar kedengaran beris...
# 6   sarapannya jam siang wilayah jakarta aktivitas...
# 7   oke housekeepingnya tolong makeup room jam pag...
# 8   makanan oke banget lengkap menunya handuk kese...
# 9   jalur masuk kamar labirin sempit makan pagi di...
# 10  kamarnya oke sayang pas dateng langsung masuk ...
# 11  enak banget hotel terletak pusat kota bioskop ...
# 12  tempatnya bagus bersih harga murah mengecewaka...
# 13  edisi menginap kali kamar kedap suara tenang i...
# 14  resepsionis peduli bangun pagi pergi skouw per...
# 15  menyenangkankecuali diperhatikan tamu isengsoa...
# 16  sudutsudut kamar kotor kamar lembab air panas ...
# 17  checkin menunggu stengah jam prepare kamarseme...
# 18  ketiga kamar pesan kamar mandi air wastafel kl...
# 19  banget sempit masuk mobil koskosan masuk permu...
#
#                                           text_tokens  \
# 0   [kehilangan, barang, kelupaan, kulkas, menghub...
# 1   [hotel, terletak, daerah, terpencil, jalan, se...
# 2   [check, innya, banget, kamar, book, jauhjauh, ...
# 3   [kalinya, keluarga, menginap, viva, hotel, pen...
# 4   [pilih, kamar, kamar, mandinya, lantai, kamar,...
# 5   [kamar, kedap, suarasuara, sangar, kedengaran,...
# 6   [sarapannya, jam, siang, wilayah, jakarta, akt...
# 7   [oke, housekeepingnya, tolong, makeup, room, j...
# 8   [makanan, oke, banget, lengkap, menunya, handu...
# 9   [jalur, masuk, kamar, labirin, sempit, makan, ...
# 10  [kamarnya, oke, sayang, pas, dateng, langsung,...
# 11  [enak, banget, hotel, terletak, pusat, kota, b...
# 12  [tempatnya, bagus, bersih, harga, murah, menge...
# 13  [edisi, menginap, kali, kamar, kedap, suara, t...
# 14  [resepsionis, peduli, bangun, pagi, pergi, sko...
# 15  [menyenangkankecuali, diperhatikan, tamu, isen...
# 16  [sudutsudut, kamar, kotor, kamar, lembab, air,...
# 17  [checkin, menunggu, stengah, jam, prepare, kam...
# 18  [ketiga, kamar, pesan, kamar, mandi, air, wast...
# 19  [banget, sempit, masuk, mobil, koskosan, masuk...
#
#                                        text_steamindo
# 0       hilang barang lupa kulkas hubung hotel respon
# 1   hotel letak daerah pencil jalan sempit bawa mo...
# 2   check innya banget kamar book jauhjauh kamar s...
# 3   kali keluarga inap viva hotel inap kali kecewa...
# 4   pilih kamar kamar mandi lantai kamar mandi gay...
# 5   kamar kedap suarasuara sangar dengar berisikap...
# 6   sarap jam siang wilayah jakarta aktivitas nasi...
# 7   oke housekeepingnya tolong makeup room jam pag...
# 8   makan oke banget lengkap menu handuk keset lan...
# 9   jalur masuk kamar labirin sempit makan pagi su...
# 10  kamar oke sayang pas dateng langsung masuk kam...
# 11  enak banget hotel letak pusat kota bioskop tin...
# 12  tempat bagus bersih harga murah kecewa jalan m...
# 13  edisi inap kali kamar kedap suara tenang istir...
# 14  resepsionis peduli bangun pagi pergi skouw bat...
# 15  menyenangkankecuali perhati tamu isengsoalnya ...
# 16  sudutsudut kamar kotor kamar lembab air panas ...
# 17  checkin tunggu stengah jam prepare kamarsement...
# 18  tiga kamar pesan kamar mandi air wastafel klos...
# 19  banget sempit masuk mobil koskosan masuk mukim...

# %%
data_clean.to_csv('hasil_PreProcessing.csv', index= False)

# %% [markdown]
# Referensi :
#
# https://www.dqlab.id/tahapan-text-preprocessing-dalam-teknik-pengolahan-data
#
# https://ksnugroho.medium.com/dasar-text-preprocessing-dengan-python-a4fa52608ffe
